# %% [markdown]
# # PyDataSG 1: Inaugural Meetup!

# %%
from IPython.display import Image
Image("https://pbs.twimg.com/media/B3gcFATCYAEZ5o1.jpg")

# %% [markdown]
# Let's start 2015 with some Python!

# %% [markdown]
# ## Check out our Facebook group!

# %% [markdown]
# https://www.facebook.com/groups/pydatasg/
#
# and Twitter too, of course https://twitter.com/pydatasg

# %% [markdown]
# ## Main talks 10-20 mins each

# %% [markdown]
# - Eugene - Getting Started with Spyre
# - Thia Kai Xin - Simple Optimization with Python
# - Martin Andrews - Theano (and GPUs)
# - Asankhaya Sharma - Visualizin Symbolic Execution with Bokeh
# - Shubham Goyal - Introduction to scikit-learn

# %% [markdown]
# ## Lightning talks 1 min each

# %% [markdown]
# Showcase your python data hacks, visuals, findings. Ask questions, learn and have fun!

# %% [markdown]
# ## Venue Sponsor

# %% [markdown]
# Thanks to our venue sponsor - [Spire Global](https://www.crunchbase.com/organization/nanosatisfi). Spire is a satellite-powered data company that tackles business challenges with data solutions for organizations.

# %% [markdown]
# ## Volunteers

# %% [markdown]
# Help organize the next PyDataSG meetup!
